# %%
import os
from datetime import date
from pymongo import MongoClient
try:
    import scrapy
except:
    # !pip install scrapy
    import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.crawler import CrawlerRunner

# %%
if os.path.isfile('/home/abc/airflow/dags/usresult.json'):
    os.remove("/home/abc/airflow/dags/usresult.json")
else:
    print ("crawling")
# Out:
# crawling

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('usresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import logging

class us(scrapy.Spider):
    name = "us"
    products = ['defense', 'complaint', 'security']

    custom_settings = {
        'LOG_LEVEL': logging.WARNING,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1},
        'FEED_FORMAT':'json',                                 
        'FEED_URI': 'usresult.json'                        
    }
    
    def start_requests(self):
        for product in self.products:
            yield scrapy.Request(
                url = f'https://www.justice.gov/news?keys={product}&items_per_page=25',callback = self.parse)
    
    def parse(self,response):
        links = response.xpath("//span[@class='field-content']/a")
        for link in links:
            link = link.xpath(".//@href").get()
            yield response.follow(url=link, callback=self.parse_justice)


    def parse_justice(self, response):
        name = response.xpath("(//h1)[2]/text()").get()
        Artical = response.xpath("//div[@class='field__item even']/p/text()").get()
        date = response.xpath("//span[@class='date-display-single']/text()").get()
        topic = response.xpath("(//div[@class='pr-fields']//div[@class='field__items']/div[@class='field__item even'])[1]/text()").get()
        component = response.xpath("//div[@class='field__items']/div[@class='field__item even']/a/text()").get()
        press_release = response.xpath("(//div[@class='pr-fields']//div[@class='field__items']/div[@class='field__item even'])[3]/text()").get()

        yield {
            'id' : name,
            'Artical':Artical,
            'Date': date,
            'Topic': topic,
            'component': component,
            'press_release': press_release
            }

# %%
process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 Mobile Safari/537.36'
})

process.crawl(us)
process.start()
# Out:
# 2022-06-07 10:24:38 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapybot)
# 2022-06-07 10:24:38 [scrapy.utils.log] INFO: Versions: lxml 4.8.0.0, libxml2 2.9.12, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.2.0, Python 3.8.10 (default, Feb  9 2022, 11:03:48) - [GCC 7.5.0], pyOpenSSL 21.0.0 (OpenSSL 1.1.1n  15 Mar 2022), cryptography 36.0.2, Platform Linux-5.4.0-113-generic-x86_64-with-glibc2.27
# 2022-06-07 10:24:38 [scrapy.crawler] INFO: Overridden settings:
# {'LOG_LEVEL': 30,
#  'USER_AGENT': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.82 '
#                'Mobile Safari/537.36'}
# 2022-06-07 10:24:38 [py.warnings] WARNING: /home/abc/.pyenv/versions/3.8.10/lib/python3.8/site-packages/scrapy/extensions/feedexport.py:289: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)

# %%
import pandas as pd
df = pd.read_json('usresult.json')
df = df.dropna()
df = df.reset_index(drop=True)
df
# Out:
#                                                    id  \
# 0   Justice Department Settles Complaint Against V...
# 1   US Settles Complaint Against Wisconsin Livesto...
# 2   United States Files False Claims Act Complaint...
# 3   U.S. Files Complaint and Consent Decree Agains...
# 4   Former DIA Employee Pleads Guilty to Leaking C...
# 5   United States Joins Suit against Navistar Defe...
# 6   Former Defense Contractor Executive Pleads Gui...
# 7   Readout of Assistant Attorney General for Nati...
# 8   Deputy Assistant Attorney General Adam Hickey ...
# 9   Former University of Wisconsin-Oshkosh Student...
# 10  Texas Man Charged by Criminal Complaint with C...
# 11  Readout of Assistant Attorney General for Nati...
# 12  Assistant Attorney General John C. Demers Deli...
# 13  Team Telecom Recommends that the FCC Deny Paci...
# 14  Acting Attorney General and Secretary of Homel...
# 15  Former Security Services Executives Plead Guil...
# 16  Social Security Disability Lawyer Pleads Guilt...
# 17   Massachusetts Man Pleads Guilty to Illegally ...
# 18  Defense Department Linguist Pleads Guilty to T...
# 19  Former Defense Contractor Manager Pleads Guilt...
# 20  Former Defense Contractor Executive Pleads Gui...
# 21  Cyber-Criminal Residing in Latvia Convicted fo...
# 22  Justice Department Files Complaint to Stop Dis...
# 23  Justice Department Reaches Agreement with City...
#
#                                               Artical       Date  \
# 0   The United States has filed suit in the U.S. D... 2013-06-20
# 1   The United States has filed suit in the U.S. D... 2012-06-26
# 2   The United States has filed a complaint agains... 2020-01-07
# 3   \nAssistant Attorney General Stuart F. Delery ... 2014-07-01
# 4   An employee of the Defense Intelligence Agency... 2020-02-20
# 5   The United States has intervened in a whistleb... 2019-12-04
# 6   An Ashland, Oregon, employee of a defense cont... 2022-02-16
# 7                                           Today at  2015-10-06
# 8   Thank you, to the Cybersecurity Coalition and ... 2018-10-04
# 9   Assistant Attorney General for National Securi... 2015-03-12
# 10  A Texas man was charged today with conspiring ... 2019-02-08
# 11  Speaking today at the French American Foundati... 2015-09-15
# 12  Today, the Justice Department is announcing ch... 2021-02-17
# 13  Team Telecom today recommended to the Federal ... 2020-06-17
# 14  Acting Attorney General Matthew G. Whitaker an... 2019-02-05
# 15  Two former employees of G4S Secure Solutions N... 2021-10-18
# 16                                                    2017-03-24
# 17  A Sharon, Massachusetts, man pleaded guilty to... 2019-12-13
# 18                                        Thompson's  2021-03-26
# 19  A former manager for a defense contractor plea... 2022-04-25
# 20  A former managing director for a defense contr... 2022-03-23
# 21  A federal jury today convicted a  Latvian “non... 2018-05-16
# 22  The United States filed a civil complaint to s... 2020-12-04
# 23  The Justice Department filed a proposed consen... 2017-02-06
#
#                                      Topic                         component  \
# 0                      Consumer Protection                    Civil Division
# 1                      Consumer Protection                    Civil Division
# 2                         False Claims Act                    Civil Division
# 3                      Consumer Protection                    Civil Division
# 4   Counterintelligence and Export Control  National Security Division (NSD)
# 5                         False Claims Act                    Civil Division
# 6                                      Tax                      Tax Division
# 7                               Cybercrime  National Security Division (NSD)
# 8                               Cybercrime  National Security Division (NSD)
# 9                        National Security  National Security Division (NSD)
# 10                        Counterterrorism  National Security Division (NSD)
# 11                   Intellectual Property  National Security Division (NSD)
# 12                              Cybercrime  National Security Division (NSD)
# 13                       National Security  National Security Division (NSD)
# 14                       National Security  National Security Division (NSD)
# 15                               Antitrust                Antitrust Division
# 16                         Financial Fraud                 Criminal Division
# 17  Counterintelligence and Export Control  National Security Division (NSD)
# 18  Counterintelligence and Export Control  National Security Division (NSD)
# 19                                     Tax                      Tax Division
# 20                                     Tax                      Tax Division
# 21                              Cybercrime                 Criminal Division
# 22                     Consumer Protection                    Civil Division
# 23                            Civil Rights             Civil Rights Division
#
#    press_release
# 0         13-699
# 1         12-810
# 2          20-04
# 3         14-689
# 4         20-211
# 5         19-344
# 6         22-134
# 7        15-1242
# 8        18-1299
# 9         15-305
# 10         19-96
# 11       15-1120
# 12        21-155
# 13        20-555
# 14         19-66
# 15       21-1015
# 16        17-318
# 17       19-1389
# 18        21-180
# 19        22-425
# 20        22-279
# 21        18-641
# 22       20-1316
# 23        17-153

# %%
# Connect to MongoDB
client =  MongoClient("mongodb+srv://atul:Eya6cxrSZJra9cM@cluster0.wmdzd.mongodb.net/myFirstDatabase?retryWrites=true&w=majority")

# %%
if os.path.isfile('/home/abc/airflow/dags/usresult.json'):
    df_data = pd.read_json('/home/abc/airflow/dags/usresult.json')
else:
    print ("File not exist")
db = client['Department']
collection = db['us_justice']

df.reset_index(inplace=True)
data_dict = df.to_dict("record")
# Insert collection
collection.insert_many(data_dict)
# Out:
# 2022-06-07 10:24:51 [py.warnings] WARNING: /tmp/ipykernel_9007/850912115.py:9: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   data_dict = df.to_dict("record")

# %%
page_title_text='My report'
title_text = 'Department of Justice'
text = 'Hello, welcome to your report!'
stats_text = 'NEWS Report'
today = f'Date--{date.today()}'


# 2. Combine them together using a long f-string
html = f'''
    <html>
        <head>
            <title>{page_title_text}</title>
        </head>
        <body>
            <h1>{title_text:^15}</h1>
            <h3>{text}</h3>
            <h4>{today}</h4>
            <h2>{stats_text}</h2>
            {df.to_html()}
        </body>
    </html>
    '''
# 3. Write the html string as an HTML file
with open('html_report.html', 'w') as f:
    f.write(html)
